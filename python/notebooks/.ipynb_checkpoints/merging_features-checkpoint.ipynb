# %%
import paths, dataframes

# %%
from pipe import select
import pandas

# %%
every_hive_audio_features = pandas.concat(
    paths.all_audio_features_csv_filepaths(hive_numbers=[1,2,3,4,5,6])
    | select(dataframes.from_filepath),
    ignore_index=True,
)

# %%
every_hive_audio_features.drop(columns=[c for c in every_hive_audio_features.columns if c.startswith("Unnamed")], inplace=True)
every_hive_audio_features.dropna()
every_hive_audio_features.head()
# Out:
#             timestamp     hive time_slice  spectral_centroid_mean  \
# 0 2026-03-07 17:00:00  hive_01      17-18             1704.839665
# 1 2026-03-07 18:00:00  hive_01      18-19             1790.814496
# 2 2026-03-07 19:00:00  hive_01      19-20             1823.045205
# 3 2026-03-07 20:00:00  hive_01      20-21             1805.283076
# 4 2026-03-07 21:00:00  hive_01      21-22             1803.259381
#
#    spectral_centroid_std  spectral_bandwidth_mean  spectral_bandwidth_std  \
# 0             191.237211              2283.109757              131.021388
# 1             309.629397              2327.348104              179.594982
# 2             315.363740              2333.649956              171.735514
# 3             191.214024              2347.317531              115.439600
# 4             147.803181              2313.412297               97.664542
#
#    spectral_rolloff_mean  spectral_rolloff_std  spectral_flatness_mean  ...  \
# 0            4787.536582            572.251570                0.020389  ...
# 1            5004.947215            650.518700                0.021843  ...
# 2            5072.253507            625.039905                0.024116  ...
# 3            5128.420892            422.853036                0.022318  ...
# 4            5032.523823            377.836613                0.025464  ...
#
#    low_to_high_energy_ratio_std  middle_to_high_energy_ratio_mean  \
# 0                      1.378878                          2.208398
# 1                      0.908164                          2.136371
# 2                      0.791499                          2.195237
# 3                      0.931899                          2.241347
# 4                      0.670456                          2.205859
#
#    middle_to_high_energy_ratio_std  low_modulation_energy  \
# 0                         0.333739           3.415686e+06
# 1                         0.167763           3.277247e+06
# 2                         0.156738           2.871789e+06
# 3                         0.177238           2.812510e+06
# 4                         0.162945           2.481559e+06
#
#    low_peak_modulation_frequency  middle_modulation_energy  \
# 0                       2.031807              3.818026e+06
# 1                       2.361399              3.380961e+06
# 2                       1.005282              3.223628e+06
# 3                       1.143894              3.075437e+06
# 4                       3.766128              2.905298e+06
#
#    middle_peak_modulation_frequency  high_modulation_energy  \
# 0                          1.288793            2.246383e+06
# 1                          5.802804            2.044457e+06
# 2                          4.194463            1.880883e+06
# 3                          2.307232            1.774921e+06
# 4                          7.159476            1.691767e+06
#
#    high_peak_modulation_frequency  queenlessness
# 0                        1.878730          False
# 1                        1.063060          False
# 2                        5.745026          False
# 3                        3.222514          False
# 4                       10.150601          False
#
# [5 rows x 106 columns]

# %%
every_hive_audio_features["queenlessness"] = every_hive_audio_features.apply(dataframes.queenstate_from_row, axis=1) == "queenless"

# %%
ambient_features = pandas.read_csv(
    paths.ambient_features_filepath, parse_dates=["timestamp"]
)

# %%
ambient_features.drop(columns=[c for c in ambient_features.columns if c.startswith("Unnamed")], inplace=True)

# %%
merged_features_dataframe = every_hive_audio_features.merge(ambient_features, on="timestamp", how="left")

# %%
dataframes.saved_csv_filepath_from_features_dataframe(
    dataframe=merged_features_dataframe,
    dataframe_filename=paths.all_merged_features_filename,
)
# Out:
# '../../data/features/all_merged_features.csv'

# %%
import os
assert os.path.isfile(paths.all_merged_features_filepath)

# %%
# which columns have NaN, and how many
merged_features_dataframe.isnull().sum()[merged_features_dataframe.isnull().sum() > 0]
# Out:
# temperature    108
# humidity       108
# dtype: int64

# %%
# rows that have any NaN
merged_features_dataframe[merged_features_dataframe.isnull().any(axis=1)]
# Out:
#               timestamp     hive time_slice  spectral_centroid_mean  \
# 781 2026-03-26 08:00:00  hive_02      08-09             1973.334612
# 782 2026-03-26 09:00:00  hive_02      09-10             2149.517285
# 783 2026-03-26 10:00:00  hive_02      10-11             2060.381450
# 784 2026-03-26 11:00:00  hive_02      11-12             1869.026789
# 785 2026-03-26 12:00:00  hive_02      12-13             1866.184583
# ..                  ...      ...        ...                     ...
# 884 2026-03-30 15:00:00  hive_02      15-16             1895.405295
# 885 2026-03-30 16:00:00  hive_02      16-17             1581.768120
# 886 2026-03-30 17:00:00  hive_02      17-18             1660.413498
# 887 2026-03-30 18:00:00  hive_02      18-19             1978.090562
# 888 2026-03-30 19:00:00  hive_02      19-20             2054.437532
#
#      spectral_centroid_std  spectral_bandwidth_mean  spectral_bandwidth_std  \
# 781             295.904410              2478.774089              119.899640
# 782             323.115456              2526.185521              117.459862
# 783             297.642097              2497.831285              117.994564
# 784             294.065130              2428.787163              134.287820
# 785             309.229293              2424.969155              159.550832
# ..                     ...                      ...                     ...
# 884             293.141050              2448.024438              159.149443
# 885             328.103924              2310.800464              169.634471
# 886             295.693547              2322.304738              141.251933
# 887             225.913045              2428.129079              108.209641
# 888             272.252831              2450.953714              247.136838
#
#      spectral_rolloff_mean  spectral_rolloff_std  spectral_flatness_mean  ...  \
# 781            5400.325323            514.523916                0.015534  ...
# 782            5616.222670            501.717018                0.032519  ...
# 783            5508.194471            546.306745                0.028317  ...
# 784            5213.698430            607.513628                0.017519  ...
# 785            5205.934574            710.356085                0.021908  ...
# ..                     ...                   ...                     ...  ...
# 884            5290.103070            674.501475                0.019465  ...
# 885            4595.993888            906.327714                0.008410  ...
# 886            4751.831504            736.107327                0.010433  ...
# 887            5353.870538            485.415503                0.031810  ...
# 888            5472.459182            617.959216                0.046996  ...
#
#      middle_to_high_energy_ratio_std  low_modulation_energy  \
# 781                         0.189469           1.704317e+06
# 782                         0.249232           1.410078e+06
# 783                         0.309431           1.601557e+06
# 784                         0.374550           1.860864e+06
# 785                         0.385188           1.887796e+06
# ..                               ...                    ...
# 884                         0.333871           2.476437e+06
# 885                         0.246121           3.563965e+06
# 886                         0.206784           2.570832e+06
# 887                         0.164780           1.478838e+06
# 888                         0.239297           4.169005e+06
#
#      low_peak_modulation_frequency  middle_modulation_energy  \
# 781                      22.502044              8.273722e+05
# 782                       1.008060              9.874623e+05
# 783                      25.283723              1.168592e+06
# 784                      12.271166              1.451901e+06
# 785                       7.500589              2.052609e+06
# ..                             ...                       ...
# 884                       1.083338              2.430514e+06
# 885                      22.188988              1.870510e+06
# 886                      22.636212              1.627361e+06
# 887                       2.235010              1.454618e+06
# 888                       1.155379              8.709506e+06
#
#      middle_peak_modulation_frequency  high_modulation_energy  \
# 781                          1.541951            5.275153e+05
# 782                          1.046949            6.159446e+05
# 783                          1.066394            7.340671e+05
# 784                          1.242783            8.579312e+05
# 785                          1.153338            1.285183e+06
# ..                                ...                     ...
# 884                          1.089172            1.516055e+06
# 885                          1.364173            1.148904e+06
# 886                          1.026949            1.015924e+06
# 887                          1.417784            9.441337e+05
# 888                          6.155407            9.408705e+06
#
#      high_peak_modulation_frequency  queenlessness  temperature  humidity
# 781                        1.098338          False          NaN       NaN
# 782                        1.688341          False          NaN       NaN
# 783                        1.257783          False          NaN       NaN
# 784                        1.124172          False          NaN       NaN
# 785                        1.455562          False          NaN       NaN
# ..                              ...            ...          ...       ...
# 884                        1.070005          False          NaN       NaN
# 885                        1.125838          False          NaN       NaN
# 886                        1.233617          False          NaN       NaN
# 887                        1.363617          False          NaN       NaN
# 888                       19.906680          False          NaN       NaN
#
# [108 rows x 108 columns]
