# %%
selected_hive_numbers = [5,6]

# %%
from pipe import take
from pipe import select
from pipe import Pipe
import timestamps_and_frames
import features
import dataframes
import paths
import times
import  pandas
sink = lambda f: Pipe(lambda iterable: f(list(iterable)))
for hive_number in selected_hive_numbers: (
    hive_number
    | paths.hive_audio_folderpath_from_hive_number
    | timestamps_and_frames.hourly_audio_from_hive_folderpath
    | features.hourly_features_from_audio_stream
    | dataframes.dataframe_from_hourly_stream(hive_number=hive_number)
    | select( lambda dataframe: 
        dataframes.saved_csv_filepath_from_features_dataframe(
            dataframe=dataframe,
            dataframe_filename=paths.audio_features_filename_from_hive_number(hive_number),
        )
    )
    | select(lambda filepath:
        pandas.read_csv(filepath, parse_dates=["timestamp"]).head()
    )
    | sink(list)
)
# Out:
# /nix/store/74c94ifq2mw9s8z6zns58vj9nfdh3cl2-python3-3.12.13-env/lib/python3.12/site-packages/librosa/core/pitch.py:103: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       7 import times
#       8 sink = lambda f: Pipe(lambda iterable: f(list(iterable)))
#       9 for hive_number in selected_hive_numbers: (
# ---> 10     hive_number
#      11     | paths.hive_audio_folderpath_from_hive_number
#      12     | timestamps_and_frames.hourly_audio_from_hive_folderpath
#      13     | features.hourly_features_from_audio_stream
#      14     | dataframes.dataframe_from_hourly_stream(hive_number=hive_number)
#      15     | select( lambda dataframe:
#      16         dataframes.saved_csv_filepath_from_features_dataframe(
#      17             dataframe=dataframe,
#      18             dataframe_filename=paths.audio_features_filename_from_hive_number(hive_number),
#      19         )
#      20     )
#      21     | select(lambda filepath:
#      22         pandas.read_csv(filepath, parse_dates=["timestamp"]).head()
#      23     )
#      24     | sink(list)
#      25 )
#
# File /nix/store/74c94ifq2mw9s8z6zns58vj9nfdh3cl2-python3-3.12.13-env/lib/python3.12/site-packages/pipe.py:42, in Pipe.__ror__(self, other)
#      41 def __ror__(self, other):
# ---> 42     return self.function(other)
#
# File /nix/store/74c94ifq2mw9s8z6zns58vj9nfdh3cl2-python3-3.12.13-env/lib/python3.12/site-packages/pipe.py:36, in Pipe.__init__.<locals>.<lambda>(iterable, *args2, **kwargs2)
#      35 def __init__(self, function, *args, **kwargs):
# ---> 36     self.function = lambda iterable, *args2, **kwargs2: function(
#      37         iterable, *args, *args2, **kwargs, **kwargs2
#      38     )
#      39     functools.update_wrapper(self, function)
#
# Cell In[2], line 8, in <lambda>(iterable)
#       6 import paths
#       7 import times
# ----> 8 sink = lambda f: Pipe(lambda iterable: f(list(iterable)))
#       9 for hive_number in selected_hive_numbers: (
#      10     hive_number
#      11     | paths.hive_audio_folderpath_from_hive_number
#    (...)     24     | sink(list)
#      25 )
#
# Cell In[2], line 22, in <lambda>(filepath)
#       7 import times
#       8 sink = lambda f: Pipe(lambda iterable: f(list(iterable)))
#       9 for hive_number in selected_hive_numbers: (
#      10     hive_number
#      11     | paths.hive_audio_folderpath_from_hive_number
#      12     | timestamps_and_frames.hourly_audio_from_hive_folderpath
#      13     | features.hourly_features_from_audio_stream
#      14     | dataframes.dataframe_from_hourly_stream(hive_number=hive_number)
#      15     | select( lambda dataframe:
#      16         dataframes.saved_csv_filepath_from_features_dataframe(
#      17             dataframe=dataframe,
#      18             dataframe_filename=paths.audio_features_filename_from_hive_number(hive_number),
#      19         )
#      20     )
#      21     | select(lambda filepath:
# ---> 22         pandas.read_csv(filepath, parse_dates=["timestamp"]).head()
#      23     )
#      24     | sink(list)
#      25 )
#
# NameError: name 'pandas' is not defined
