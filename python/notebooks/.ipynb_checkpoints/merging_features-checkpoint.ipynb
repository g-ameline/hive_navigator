# %%
import paths, dataframes

# %%
from pipe import select
import pandas

# %%
every_hive_audio_features = pandas.concat(
    paths.all_audio_features_csv_filepaths(hive_numbers=[1,2,3,4,5,6])
    | select(dataframes.from_filepath),
    ignore_index=True,
)

# %%
every_hive_audio_features.drop(columns=[c for c in dataframe.columns if c.startswith("Unnamed")], inplace=True)
every_hive_audio_features.head()
# Out:
#    Unnamed: 0           timestamp     hive time_slice  spectral_centroid_mean  \
# 0           0 2026-03-07 17:00:00  hive_01      17-18             1704.839665
# 1           1 2026-03-07 18:00:00  hive_01      18-19             1790.814496
# 2           2 2026-03-07 19:00:00  hive_01      19-20             1823.045205
# 3           3 2026-03-07 20:00:00  hive_01      20-21             1805.283076
# 4           4 2026-03-07 21:00:00  hive_01      21-22             1803.259381
#
#    spectral_centroid_std  spectral_bandwidth_mean  spectral_bandwidth_std  \
# 0             191.237211              2283.109757              131.021388
# 1             309.629397              2327.348104              179.594982
# 2             315.363740              2333.649956              171.735514
# 3             191.214024              2347.317531              115.439600
# 4             147.803181              2313.412297               97.664542
#
#    spectral_rolloff_mean  spectral_rolloff_std  ...  \
# 0            4787.536582            572.251570  ...
# 1            5004.947215            650.518700  ...
# 2            5072.253507            625.039905  ...
# 3            5128.420892            422.853036  ...
# 4            5032.523823            377.836613  ...
#
#    low_to_high_energy_ratio_mean  low_to_high_energy_ratio_std  \
# 0                       2.975306                      1.378878
# 1                       3.089824                      0.908164
# 2                       2.926316                      0.791499
# 3                       3.067312                      0.931899
# 4                       2.758642                      0.670456
#
#    middle_to_high_energy_ratio_mean  middle_to_high_energy_ratio_std  \
# 0                          2.208398                         0.333739
# 1                          2.136371                         0.167763
# 2                          2.195237                         0.156738
# 3                          2.241347                         0.177238
# 4                          2.205859                         0.162945
#
#    low_modulation_energy  low_peak_modulation_frequency  \
# 0           3.415686e+06                       2.031807
# 1           3.277247e+06                       2.361399
# 2           2.871789e+06                       1.005282
# 3           2.812510e+06                       1.143894
# 4           2.481559e+06                       3.766128
#
#    middle_modulation_energy  middle_peak_modulation_frequency  \
# 0              3.818026e+06                          1.288793
# 1              3.380961e+06                          5.802804
# 2              3.223628e+06                          4.194463
# 3              3.075437e+06                          2.307232
# 4              2.905298e+06                          7.159476
#
#    high_modulation_energy  high_peak_modulation_frequency
# 0            2.246383e+06                        1.878730
# 1            2.044457e+06                        1.063060
# 2            1.880883e+06                        5.745026
# 3            1.774921e+06                        3.222514
# 4            1.691767e+06                       10.150601
#
# [5 rows x 106 columns]

# %%
every_hive_audio_features["queenlessness"] = every_hive_audio_features.apply(dataframes.queenstate_from_row, axis=1) == "queenless"

# %%
ambient_features = pandas.read_csv(
    paths.ambient_features_filepath, parse_dates=["timestamp"]
)

# %%
merged_features_dataframe = every_hive_audio_features.merge(ambient_features, on="timestamp", how="left")

# %%
dataframes.saved_csv_filepath_from_features_dataframe(
    dataframe=merged_features_dataframe,
    dataframe_filename=paths.all_merged_features_filename,
)
# Out:
# '../../data/features/all_merged_features.csv'

# %%
import os
assert os.path.isfile(paths.all_merged_features_filepath)

# %%
merged_features_dataframe
# Out:
#       Unnamed: 0           timestamp     hive time_slice  \
# 0              0 2026-03-07 17:00:00  hive_01      17-18
# 1              1 2026-03-07 18:00:00  hive_01      18-19
# 2              2 2026-03-07 19:00:00  hive_01      19-20
# 3              3 2026-03-07 20:00:00  hive_01      20-21
# 4              4 2026-03-07 21:00:00  hive_01      21-22
# ...          ...                 ...      ...        ...
# 1850         296 2026-03-25 13:00:00  hive_06      13-14
# 1851         297 2026-03-25 14:00:00  hive_06      14-15
# 1852         298 2026-03-25 15:00:00  hive_06      15-16
# 1853         299 2026-03-25 16:00:00  hive_06      16-17
# 1854         300 2026-03-25 17:00:00  hive_06      17-18
#
#       spectral_centroid_mean  spectral_centroid_std  spectral_bandwidth_mean  \
# 0                1704.839665             191.237211              2283.109757
# 1                1790.814496             309.629397              2327.348104
# 2                1823.045205             315.363740              2333.649956
# 3                1805.283076             191.214024              2347.317531
# 4                1803.259381             147.803181              2313.412297
# ...                      ...                    ...                      ...
# 1850             1399.256072             313.278141              2004.146901
# 1851             1494.794703             393.775712              2059.307674
# 1852             1469.659797             492.257647              2040.221765
# 1853             1495.790825             364.202036              2063.282529
# 1854             1523.128075             393.537238              2103.068647
#
#       spectral_bandwidth_std  spectral_rolloff_mean  spectral_rolloff_std  \
# 0                 131.021388            4787.536582            572.251570
# 1                 179.594982            5004.947215            650.518700
# 2                 171.735514            5072.253507            625.039905
# 3                 115.439600            5128.420892            422.853036
# 4                  97.664542            5032.523823            377.836613
# ...                      ...                    ...                   ...
# 1850              188.007061            3384.475622            862.307150
# 1851              216.553803            3657.930824           1000.955182
# 1852              268.665312            3561.449368           1080.449885
# 1853              178.437020            3664.846784            873.607756
# 1854              213.508552            3796.375614           1023.262462
#
#       ...  middle_to_high_energy_ratio_std  low_modulation_energy  \
# 0     ...                         0.333739           3.415686e+06
# 1     ...                         0.167763           3.277247e+06
# 2     ...                         0.156738           2.871789e+06
# 3     ...                         0.177238           2.812510e+06
# 4     ...                         0.162945           2.481559e+06
# ...   ...                              ...                    ...
# 1850  ...                         0.315685           6.314395e+06
# 1851  ...                         0.339153           6.879034e+06
# 1852  ...                         0.384166           8.698996e+06
# 1853  ...                         0.178336           6.177729e+06
# 1854  ...                         0.168550           5.477838e+06
#
#       low_peak_modulation_frequency  middle_modulation_energy  \
# 0                          2.031807              3.818026e+06
# 1                          2.361399              3.380961e+06
# 2                          1.005282              3.223628e+06
# 3                          1.143894              3.075437e+06
# 4                          3.766128              2.905298e+06
# ...                             ...                       ...
# 1850                      13.129503              3.833401e+06
# 1851                      12.879224              4.142912e+06
# 1852                      13.079780              1.129382e+07
# 1853                       1.103616              3.176713e+06
# 1854                       1.169106              2.805889e+06
#
#       middle_peak_modulation_frequency  high_modulation_energy  \
# 0                             1.288793            2.246383e+06
# 1                             5.802804            2.044457e+06
# 2                             4.194463            1.880883e+06
# 3                             2.307232            1.774921e+06
# 4                             7.159476            1.691767e+06
# ...                                ...                     ...
# 1850                          1.041949            2.764736e+06
# 1851                          1.097783            3.054630e+06
# 1852                          1.006116            1.180773e+07
# 1853                          1.070560            2.421225e+06
# 1854                          1.147076            2.021139e+06
#
#       high_peak_modulation_frequency  queenlessness  temperature   humidity
# 0                           1.878730          False     5.045000  54.070000
# 1                           1.063060          False     4.477500  56.215000
# 2                           5.745026          False     3.640000  72.297500
# 3                           3.222514          False     2.862500  74.245000
# 4                          10.150601          False     2.760000  70.950000
# ...                              ...            ...          ...        ...
# 1850                        1.183616          False    13.860001  51.765000
# 1851                        1.096949          False    14.230000  50.920000
# 1852                        1.006116          False    14.625000  47.690000
# 1853                        1.050282          False    14.300000  46.510002
# 1854                        1.043175          False    13.985001  49.880000
#
# [1855 rows x 109 columns]
