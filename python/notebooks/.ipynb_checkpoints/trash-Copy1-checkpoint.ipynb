# %%
selected_hive_numbers = [1,2]

# %%
from pipe import select
import timestamps_and_frames
import features
import dataframes
import paths
import times

for hive_number in selected_hive_numbers: (
    hive_number
    | paths.hive_audio_folderpath_from_hive_number
    | timestamps_and_frames.hourly_audio_from_hive_folderpath
    | features.hourly_features_from_audio_stream
    | dataframes.dataframe_from_hourly_stream(hive_number=hive_number)
    | select( lambda dataframe: 
        dataframes.saved_csv_filepath_from_features_dataframe(
            dataframe=dataframe,
            dataframe_filename=paths.audio_features_filename_from_hive_number(hive_number),
        )
    )
    | select( lambda hive_number:
        pandas.read_csv(filepath, parse_dates=["timestamp"]).head()
    )
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 9
#       5 import paths
#       6 import times
#       8 for hive_number in selected_hive_numbers: (
# ----> 9     hive_number
#      10     | paths.hive_audio_folderpath_from_hive_number
#      11     | timestamps_and_frames.hourly_audio_from_hive_folderpath
#      12     | features.hourly_features_from_audio_stream
#      13     | dataframes.dataframe_from_hourly_stream(hive_number=hive_number)
#      14     | select( lambda dataframe:
#      15         dataframes.saved_csv_filepath_from_features_dataframe(
#      16             dataframe=dataframe,
#      17             dataframe_filename=paths.audio_features_filename_from_hive_number(hive_number),
#      18         )
#      19     )
#      20     | select( lambda hive_number:
#      21         pandas.read_csv(filepath, parse_dates=["timestamp"]).head()
#      22     )
#      23 )
#
# File /nix/store/74c94ifq2mw9s8z6zns58vj9nfdh3cl2-python3-3.12.13-env/lib/python3.12/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /nix/store/74c94ifq2mw9s8z6zns58vj9nfdh3cl2-python3-3.12.13-env/lib/python3.12/site-packages/pandas/core/arraylike.py:78, in OpsMixin.__or__(self, other)
#      76 @unpack_zerodim_and_defer("__or__")
#      77 def __or__(self, other):
# ---> 78     return self._logical_method(other, operator.or_)
#
# File /nix/store/74c94ifq2mw9s8z6zns58vj9nfdh3cl2-python3-3.12.13-env/lib/python3.12/site-packages/pandas/core/frame.py:7935, in DataFrame._arith_method(self, other, op)
#    7932 self, other = self._align_for_op(other, axis, flex=True, level=None)
#    7934 with np.errstate(all="ignore"):
# -> 7935     new_data = self._dispatch_frame_op(other, op, axis=axis)
#    7936 return self._construct_result(new_data)
#
# File /nix/store/74c94ifq2mw9s8z6zns58vj9nfdh3cl2-python3-3.12.13-env/lib/python3.12/site-packages/pandas/core/frame.py:7967, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    7964 right = lib.item_from_zerodim(right)
#    7965 if not is_list_like(right):
#    7966     # i.e. scalar, faster than checking np.ndim(right) == 0
# -> 7967     bm = self._mgr.apply(array_op, right=right)
#    7968     return self._constructor_from_mgr(bm, axes=bm.axes)
#    7970 elif isinstance(right, DataFrame):
#
# File /nix/store/74c94ifq2mw9s8z6zns58vj9nfdh3cl2-python3-3.12.13-env/lib/python3.12/site-packages/pandas/core/internals/managers.py:361, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     358             kwargs[k] = obj[b.mgr_locs.indexer]
#     360 if callable(f):
# --> 361     applied = b.apply(f, **kwargs)
#     362 else:
#     363     applied = getattr(b, f)(**kwargs)
#
# File /nix/store/74c94ifq2mw9s8z6zns58vj9nfdh3cl2-python3-3.12.13-env/lib/python3.12/site-packages/pandas/core/internals/blocks.py:398, in Block.apply(self, func, **kwargs)
#     395 result = func(self.values, **kwargs)
#     397 result = maybe_coerce_values(result)
# --> 398 return self._split_op_result(result)
#
# File /nix/store/74c94ifq2mw9s8z6zns58vj9nfdh3cl2-python3-3.12.13-env/lib/python3.12/site-packages/pandas/core/internals/blocks.py:419, in Block._split_op_result(self, result)
#     416 @final
#     417 def _split_op_result(self, result: ArrayLike) -> list[Block]:
#     418     # See also: split_and_operate
# --> 419     if result.ndim > 1 and isinstance(result.dtype, ExtensionDtype):
#     420         # TODO(EA2D): unnecessary with 2D EAs
#     421         # if we get a 2D ExtensionArray, we need to split it into 1D pieces
#     422         nbs = []
#     423         for i, loc in enumerate(self._mgr_locs):
#
# AttributeError: 'map' object has no attribute 'ndim'

# %%
selected_hive_numbers = [3,4]

# %%
from pipe import select
import timestamps_and_frames
import features
import dataframes
import paths
import times

for hive_number in selected_hive_numbers: (
    hive_number
    | paths.hive_audio_folderpath_from_hive_number
    | timestamps_and_frames.hourly_audio_from_hive_folderpath
    | features.hourly_features_from_audio_stream
    | dataframes.dataframe_from_hourly_stream(hive_number=hive_number)
    | select( lambda dataframe: 
        dataframes.saved_csv_filepath_from_features_dataframe(
            dataframe=dataframe,
            dataframe_filename=paths.audio_features_filename_from_hive_number(hive_number),
        )
    )
    | select( lambda hive_number:
        pandas.read_csv(filepath, parse_dates=["timestamp"]).head()
    )
)

# %%
raise

# %%
from pipe import take

import timestamps_and_frames
import features
import dataframes
import paths
import times

test_dataframe = (
    3
    | paths.hive_audio_folderpath_from_hive_number
    | timestamps_and_frames.hourly_audio_from_hive_folderpath
    # | take(10)
    | features.hourly_features_from_audio_stream
    | dataframes.dataframe_from_hourly_stream(hive_name="hive_03")
)
print(test_dataframe.shape)
print(test_dataframe.columns.tolist())
test_dataframe
# Out:
# (336, 105)
# ['timestamp', 'hive', 'time_slice', 'spectral_centroid_mean', 'spectral_centroid_std', 'spectral_bandwidth_mean', 'spectral_bandwidth_std', 'spectral_rolloff_mean', 'spectral_rolloff_std', 'spectral_flatness_mean', 'spectral_flatness_std', 'spectral_crest_mean', 'spectral_crest_std', 'spectral_entropy_mean', 'spectral_entropy_std', 'spectral_skewness_mean', 'spectral_skewness_std', 'spectral_kurtosis_mean', 'spectral_kurtosis_std', 'spectral_flux_mean', 'spectral_flux_std', 'mel_frequency_cepstral_coefficients_0_mean', 'mel_frequency_cepstral_coefficients_0_std', 'mel_frequency_cepstral_coefficients_1_mean', 'mel_frequency_cepstral_coefficients_1_std', 'mel_frequency_cepstral_coefficients_2_mean', 'mel_frequency_cepstral_coefficients_2_std', 'mel_frequency_cepstral_coefficients_3_mean', 'mel_frequency_cepstral_coefficients_3_std', 'mel_frequency_cepstral_coefficients_4_mean', 'mel_frequency_cepstral_coefficients_4_std', 'mel_frequency_cepstral_coefficients_5_mean', 'mel_frequency_cepstral_coefficients_5_std', 'mel_frequency_cepstral_coefficients_6_mean', 'mel_frequency_cepstral_coefficients_6_std', 'mel_frequency_cepstral_coefficients_7_mean', 'mel_frequency_cepstral_coefficients_7_std', 'mel_frequency_cepstral_coefficients_8_mean', 'mel_frequency_cepstral_coefficients_8_std', 'mel_frequency_cepstral_coefficients_9_mean', 'mel_frequency_cepstral_coefficients_9_std', 'mel_frequency_cepstral_coefficients_10_mean', 'mel_frequency_cepstral_coefficients_10_std', 'mel_frequency_cepstral_coefficients_11_mean', 'mel_frequency_cepstral_coefficients_11_std', 'mel_frequency_cepstral_coefficients_12_mean', 'mel_frequency_cepstral_coefficients_12_std', 'chroma_0_mean', 'chroma_0_std', 'chroma_1_mean', 'chroma_1_std', 'chroma_2_mean', 'chroma_2_std', 'chroma_3_mean', 'chroma_3_std', 'chroma_4_mean', 'chroma_4_std', 'chroma_5_mean', 'chroma_5_std', 'chroma_6_mean', 'chroma_6_std', 'chroma_7_mean', 'chroma_7_std', 'chroma_8_mean', 'chroma_8_std', 'chroma_9_mean', 'chroma_9_std', 'chroma_10_mean', 'chroma_10_std', 'chroma_11_mean', 'chroma_11_std', 'zero_crossing_rate_mean', 'zero_crossing_rate_std', 'root_mean_square_energy_mean', 'root_mean_square_energy_std', 'low_root_mean_square_energy_mean', 'low_root_mean_square_energy_std', 'low_spectral_centroid_mean', 'low_spectral_centroid_std', 'low_spectral_bandwidth_mean', 'low_spectral_bandwidth_std', 'middle_root_mean_square_energy_mean', 'middle_root_mean_square_energy_std', 'middle_spectral_centroid_mean', 'middle_spectral_centroid_std', 'middle_spectral_bandwidth_mean', 'middle_spectral_bandwidth_std', 'high_root_mean_square_energy_mean', 'high_root_mean_square_energy_std', 'high_spectral_centroid_mean', 'high_spectral_centroid_std', 'high_spectral_bandwidth_mean', 'high_spectral_bandwidth_std', 'low_to_middle_energy_ratio_mean', 'low_to_middle_energy_ratio_std', 'low_to_high_energy_ratio_mean', 'low_to_high_energy_ratio_std', 'middle_to_high_energy_ratio_mean', 'middle_to_high_energy_ratio_std', 'low_modulation_energy', 'low_peak_modulation_frequency', 'middle_modulation_energy', 'middle_peak_modulation_frequency', 'high_modulation_energy', 'high_peak_modulation_frequency']
#               timestamp     hive time_slice  spectral_centroid_mean  \
# 0   2026-03-07 17:00:00  hive_03      17-18             1720.485458
# 1   2026-03-07 18:00:00  hive_03      18-19             1908.538224
# 2   2026-03-07 19:00:00  hive_03      19-20             2001.207669
# 3   2026-03-07 20:00:00  hive_03      20-21             2070.620881
# 4   2026-03-07 21:00:00  hive_03      21-22             2078.206477
# ..                  ...      ...        ...                     ...
# 331 2026-03-21 12:00:00  hive_03      12-13             1704.899687
# 332 2026-03-21 13:00:00  hive_03      13-14             1658.207778
# 333 2026-03-21 14:00:00  hive_03      14-15             1611.940591
# 334 2026-03-21 15:00:00  hive_03      15-16             1723.165802
# 335 2026-03-21 16:00:00  hive_03      16-17             1788.105308
#
#      spectral_centroid_std  spectral_bandwidth_mean  spectral_bandwidth_std  \
# 0               232.069702              2371.472277              166.187275
# 1               193.910995              2493.285954              123.051089
# 2               178.871697              2558.319844              103.371711
# 3               187.920462              2609.062421              101.910612
# 4               186.979468              2603.074355              104.716745
# ..                     ...                      ...                     ...
# 331             170.921731              2193.658657              133.636790
# 332             254.966467              2134.904009              150.863012
# 333             292.272857              2106.107958              312.688169
# 334             211.761098              2272.016025              219.135297
# 335             165.458835              2294.174927              109.166862
#
#      spectral_rolloff_mean  spectral_rolloff_std  spectral_flatness_mean  ...  \
# 0              4911.405814            806.955256                0.017425  ...
# 1              5516.659536            610.277420                0.022098  ...
# 2              5823.240172            489.206644                0.024446  ...
# 3              6025.226281            451.158535                0.025869  ...
# 4              6042.973885            471.465026                0.026996  ...
# ..                     ...                   ...                     ...  ...
# 331            4266.419919            611.601062                0.029027  ...
# 332            4026.783581            695.565010                0.028039  ...
# 333            4024.415752            923.851537                0.041135  ...
# 334            4702.131546            654.783365                0.033157  ...
# 335            4843.332873            485.358495                0.029725  ...
#
#      low_to_high_energy_ratio_mean  low_to_high_energy_ratio_std  \
# 0                         3.937880                      1.812322
# 1                         3.880257                      1.650862
# 2                         3.675773                      1.443425
# 3                         3.497148                      1.389819
# 4                         3.277365                      1.422917
# ..                             ...                           ...
# 331                       0.922172                      0.277430
# 332                       1.301029                      0.807858
# 333                       1.520432                      0.580757
# 334                       2.213126                      0.800337
# 335                       2.310272                      0.810408
#
#      middle_to_high_energy_ratio_mean  middle_to_high_energy_ratio_std  \
# 0                            2.352812                         0.494150
# 1                            2.269834                         0.245992
# 2                            2.308208                         0.234898
# 3                            2.354404                         0.255400
# 4                            2.403785                         0.218231
# ..                                ...                              ...
# 331                          1.815232                         0.277690
# 332                          1.890659                         0.337005
# 333                          1.965728                         0.359920
# 334                          2.165523                         0.290815
# 335                          2.234434                         0.293072
#
#      low_modulation_energy  low_peak_modulation_frequency  \
# 0             2.809810e+06                       2.140644
# 1             2.349438e+06                       1.055005
# 2             2.039717e+06                       1.007782
# 3             1.903201e+06                       1.066949
# 4             1.641518e+06                       5.355857
# ..                     ...                            ...
# 331           2.740152e+06                      10.426713
# 332           3.479920e+06                       1.095005
# 333           7.079209e+06                       2.075009
# 334           7.259421e+06                       6.098916
# 335           1.534980e+06                       6.308683
#
#      middle_modulation_energy  middle_peak_modulation_frequency  \
# 0                2.875561e+06                          1.444810
# 1                2.171235e+06                          1.639174
# 2                2.003132e+06                          8.272537
# 3                1.967840e+06                          2.986124
# 4                1.837833e+06                          5.929471
# ..                        ...                               ...
# 331              8.475324e+06                          1.301672
# 332              8.127734e+06                          1.328061
# 333              1.502906e+07                          1.014449
# 334              1.467350e+07                         21.938986
# 335              2.248688e+06                          2.233097
#
#      high_modulation_energy  high_peak_modulation_frequency
# 0              1.573497e+06                        1.034062
# 1              1.248642e+06                        2.209454
# 2              1.111412e+06                        1.853064
# 3              1.061806e+06                        1.116394
# 4              9.574303e+05                        1.443618
# ..                      ...                             ...
# 331            5.911568e+06                        1.941953
# 332            5.297494e+06                        1.600007
# 333            1.527384e+07                        1.339450
# 334            1.506581e+07                        1.373062
# 335            1.224215e+06                        7.893224
#
# [336 rows x 105 columns]

# %%
import matplotlib.pyplot
import matplotlib.dates

plot_features = [
    "root_mean_square_energy_mean",
    "spectral_centroid_mean",
    "spectral_flatness_mean",
    "spectral_flux_mean",
    "high_root_mean_square_energy_mean",
    "low_to_high_energy_ratio_mean",
    "low_modulation_energy",
    "zero_crossing_rate_mean",
]

existing = [f for f in plot_features if f in test_dataframe.columns]
dates = matplotlib.dates.date2num(test_dataframe["timestamp"])

figure, axes = matplotlib.pyplot.subplots(
    len(existing), 1,
    figsize=(18, 3 * len(existing)),
    sharex=True,
)

for axis, name in zip(axes, existing):
    axis.plot_date(dates, test_dataframe[name].values, fmt="o-", markersize=3, linewidth=0.8)
    axis.set_ylabel(name, fontsize=7)
    axis.xaxis.set_major_locator(matplotlib.dates.DayLocator())
    axis.xaxis.set_major_formatter(matplotlib.dates.DateFormatter("%m/%d"))
    axis.xaxis.set_minor_locator(matplotlib.dates.HourLocator(interval=6))
    axis.xaxis.set_minor_formatter(matplotlib.dates.DateFormatter("%H:%M"))
    axis.tick_params(axis="x", which="minor", labelsize=5, rotation=45)
    axis.tick_params(axis="x", which="major", labelsize=7, rotation=45)
    axis.grid(which="major", alpha=0.3)
    axis.grid(which="minor", alpha=0.1)

figure.suptitle("hive 03 — hourly features")
figure.tight_layout()
matplotlib.pyplot.show()
# Out:
# /tmp/nix-shell.Z5ONxU/ipykernel_1965179/3742090333.py:25: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   axis.plot_date(dates, test_dataframe[name].values, fmt="o-", markersize=3, linewidth=0.8)

# %%
raise
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 raise
#
# RuntimeError: No active exception to reraise

# %%
from pipe import select, chain, where, take, tee, Pipe, sort

stow = lambda f: Pipe(lambda args, **kwargs: f(*args, **kwargs))
compose = lambda f, g: (lambda *args, **kwargs: g(*f(*args, **kwargs)))
sink = lambda f: Pipe(lambda iterable: f(list(iterable)))
def identity(x): return x
