# %% [markdown]
# # anomaly detection — summary
#
# ## method
# one-class support vector machine trained on queenright data only (all hives, all hours).
# the model learns the "normal" feature envelope; queenless observations are scored as novelty.
#
# per-time-slice scoring: one scaler + one detector fitted per hour slice,
# so the model does not confuse day/night variation with anomaly.
#
# the feature are filtered to keep only the ones whose zscore diverge between queenright and queenless data
#
# ## evaluation
# - anomaly score histograms: visual check that queenless scores shift left (more anomalous)
# - mann–whitney u test + area under the receiver operating characteristic curve:
#   non-parametric measure of how separable the two populations are
# - cohen's d: effect size in pooled standard deviations
#
# ## mosaic visualisation
# rows = hourly observations, columns = features (z-scored against queenright baseline).
# left strip = anomaly score (darker = more anomalous, red border = bottom 1st percentile).
# baseline panel shows the same time window aggregated across queenright hives
# (mean, worst, furthest from centroid, or single hive selectable).
# columns are reordered by feature similarity for visual clustering.
#
# ## findings
# - hive 04 queenless period is well separated from baseline
# - hive 03 queenless period shows weaker separation if any
# - mosaic heatmap highlight which features deviate most during queenlessness
#   - anomaly score is displayed vertically and shows at what hour the data diverge from baseline
#   - if dsipalyed via matplotlib :
#     - columns are cluster according to common information
#     - feature from the same group share same color scale

# %%
import dataframes
import anomalies
import paths
import numpy
import pandas

# %%
all_features = dataframes.from_filepath(paths.all_merged_features_filepath)
all_features = all_features.drop_duplicates(subset=["timestamp", "time_slice", "hive"], keep="first")
all_features =all_features.dropna()

# %%
all_features.head()
# Out:
#             timestamp     hive time_slice  spectral_centroid_mean  \
# 0 2026-03-07 17:00:00  hive_01      17-18             1436.880370
# 1 2026-03-07 18:00:00  hive_01      18-19             1556.936054
# 2 2026-03-08 07:00:00  hive_01      07-08             1339.847368
# 3 2026-03-08 08:00:00  hive_01      08-09             1577.337881
# 4 2026-03-08 09:00:00  hive_01      09-10             1364.667436
#
#    spectral_centroid_std  spectral_bandwidth_mean  spectral_bandwidth_std  \
# 0             254.820748              2126.972494              213.651310
# 1             206.016975              2218.712329              140.366414
# 2             195.620321              1994.812622              145.244711
# 3             246.118354              2120.288059              278.308385
# 4             201.022314              2051.912945              157.315150
#
#    spectral_rolloff_mean  spectral_rolloff_std  spectral_flatness_mean  ...  \
# 0            3888.668335            983.172022                0.009998  ...
# 1            4486.925926            606.595246                0.012219  ...
# 2            3470.113293            668.707598                0.008959  ...
# 3            4233.065704            638.337021                0.034418  ...
# 4            3685.908598            722.311976                0.008240  ...
#
#    middle_to_high_energy_ratio_std  low_modulation_energy  \
# 0                         0.447971           3.347682e+06
# 1                         0.288759           4.158193e+04
# 2                         0.475835           6.614851e+05
# 3                         0.352719           6.197887e+06
# 4                         0.361065           2.875560e+06
#
#    low_peak_modulation_frequency  middle_modulation_energy  \
# 0                       2.031807              3.600953e+06
# 1                       1.123286              4.094515e+04
# 2                       1.731035              5.762245e+05
# 3                       1.076116              1.233090e+07
# 4                       1.369173              2.206735e+06
#
#    middle_peak_modulation_frequency  high_modulation_energy  \
# 0                          1.288793            1.945159e+06
# 1                          7.488570            2.257747e+04
# 2                          1.229742            2.914703e+05
# 3                          1.525840            1.318154e+07
# 4                          3.983351            1.164676e+06
#
#    high_peak_modulation_frequency  queenlessness  temperature  humidity
# 0                        1.108633          False       5.0450   54.0700
# 1                        3.561997          False       4.4775   56.2150
# 2                        5.090786          False      -0.3500   77.2950
# 3                        1.588896          False       2.4100   78.5575
# 4                        1.424729          False       4.1050   58.9750
#
# [5 rows x 366 columns]

# %%
def dataframe_without_glitched_rows(dataframe, zscore_threshold=10, min_extreme_ratio=0.5):
    import dataframes as dataframes_module

    numeric_columns = dataframes_module.numeric_columns_from_dataframe(dataframe)
    medians = dataframe[numeric_columns].median()
    mad = (dataframe[numeric_columns] - medians).abs().median()
    mad = mad.replace(0, float('nan'))
    robust_zscores = (dataframe[numeric_columns] - medians) / (1.4826 * mad)

    extreme_ratio_per_row = (robust_zscores.abs() > zscore_threshold).sum(axis=1) / len(numeric_columns)
    glitched_mask = extreme_ratio_per_row >= min_extreme_ratio

    print(f"dropping {glitched_mask.sum()} glitched rows out of {len(dataframe)}")
    return dataframe[~glitched_mask]

# %%
all_features= dataframe_without_glitched_rows(all_features)
# Out:
# dropping 2 glitched rows out of 648

# %% [markdown]
# ## focused periods of the day
# I make the educated guess that activity is higher during daylight

# %%
# all_features =all_features[
#     all_features['time_slice'].isin([
#         # '00-01', 
#         # '01-02', 
#         # '02-03', 
#         # '03-04', 
#         # '04-05', 
#         # '05-06', 
#         # '06-07', 
#         # '07-08', 
#         # '08-09',     
#         '10-11', 
#         '11-12', 
#         '12-13', 
#         '13-14', 
#         '14-15', 
#         '15-16', 
#         '16-17', 
#         # '17-18',
#         # '18-19', 
#         # '19-20', 
#         # '20-21',
#         # '21-22',
#         # '22-23',
#         # '23-24',
#     ]
# )]

# %% [markdown]
# ## clusterings
# principal component analysis display data on a new coordiante system
# where divergence between data is exacerbated
# ***queenless data does not exhibit remarbaly different pattern from queenright data whether we compare it with the same beehive data or different beehives***

# %%
anomalies.principal_component_analysis_figure_from_dataframe(all_features)

# %% [markdown]
# ## split data into queenless and queenright
# - we split queenless data per hive
# - queenrght data is kept as is

# %%
queenright_features_dataframe = all_features[all_features['queenlessness'] == False]
queenless_features_dataframe = all_features[all_features['queenlessness'] == True]

# %%
queenless_features_dataframe_hive_03 = queenless_features_dataframe[
    queenless_features_dataframe['hive'] == "hive_03"
]
queenless_features_dataframe_hive_04 = queenless_features_dataframe[
    queenless_features_dataframe['hive'] == "hive_04"
]

# %% [markdown]
# ## features selection
# keeping only features/columns which shows divergence between queenless and queenright data

# %%
preselected_feature_columns = anomalies.most_anomalous_feature_columns(
    [
        queenless_features_dataframe_hive_03,
        queenless_features_dataframe_hive_04,
    ],
    queenright_features_dataframe
)
# preselected_feature_columns= all_features.columns

# %%
preselected_feature_columns
# Out:
# ['chroma_9_mean',
#  'mel_frequency_cepstral_coefficients_3_mean',
#  'chroma_10_mean',
#  'gammatone_frequency_cepstral_coefficients_7_mean',
#  'gammatone_frequency_cepstral_coefficients_3_mean',
#  'low_spectral_bandwidth_mean',
#  'mel_frequency_cepstral_coefficients_7_mean',
#  'middle_spectral_bandwidth_mean',
#  'zero_crossing_rate_mean',
#  'audio_band_density_ratio_mean',
#  'chroma_5_std',
#  'chroma_3_mean',
#  'chroma_9_std',
#  'high_root_mean_square_energy_mean',
#  'chroma_2_mean',
#  'linear_frequency_cepstral_coefficients_9_mean',
#  'gammatone_frequency_cepstral_coefficients_9_mean',
#  'gammatone_frequency_cepstral_coefficients_11_mean',
#  'middle_spectral_centroid_mean',
#  'chroma_4_mean',
#  'timestamp',
#  'hive',
#  'time_slice',
#  'queenlessness',
#  'temperature',
#  'humidity']

# %%
queenright_features_dataframe = queenright_features_dataframe[preselected_feature_columns]
queenless_features_dataframe = queenless_features_dataframe[preselected_feature_columns]
queenless_features_dataframe_hive_03 = queenless_features_dataframe_hive_03[preselected_feature_columns]
queenless_features_dataframe_hive_04 = queenless_features_dataframe_hive_04[preselected_feature_columns]

# %%
queenright_features_dataframe_hive_03 = queenright_features_dataframe[
    queenright_features_dataframe['hive'] == "hive_03"
]
queenright_features_dataframe_hive_04 = queenright_features_dataframe[
    queenright_features_dataframe['hive'] == "hive_04"
]

# %% [markdown]
# ## clustering with filtered fetures
# we run the principal component analysis with the slected subset of columns
# ***we still notice more different patterns from one beehive to another as opposed to from queenless to queenright states***

# %%
anomalies.principal_component_analysis_figure_from_dataframe(all_features).savefig(
    paths.pictures_folderpath + 'pca_hive_and_queenelessness_wise', 
    dpi=150,
);

# %% [markdown]
# ## anomaly detector choice
# we choose between three anomaly detection methods:
# - islation frest
# - local outlier factor
# - support vetor machine
#
# They compute distance from a list a zscore to another one in different manners
#
# ***range of output value is different but actual discrimination power do not really vary between different detectors***

# %%
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM

anomaly_detectors = {
    'isolation_forest': IsolationForest(random_state=42),
    'local_outlier_factor': LocalOutlierFactor(novelty=True),
    'svm': OneClassSVM(),
}

# %%
def anomaly_scores_from_dataframe_from_inliers_dataframe(inliers_dataframe):
    scorers = anomalies.scorers_from_inliers_dataframe_and_detector(
        inliers_dataframe,
        anomaly_detectors['isolation_forest'],
    )
    return lambda dataframe: anomalies.anomaly_scores_from_dataframe_and_scorers(dataframe, scorers)

# %%
anomaly_scores_from_dataframe = anomaly_scores_from_dataframe_from_inliers_dataframe(
    queenright_features_dataframe
)

# %% [markdown]
# ## anomaly discrimination test evaluation
# we provide 2 dataframes, baseline and investigated
# ### left graph
# we compare the anomaly score of both data as distributions
# negative values (toward left) are more abnormal/outlier
# thus the more the distribution is distributed to the left the more abnormal
# the vertical line, median is a good single indicator of it
# ### right graph
# Evaluate hwo reliable it is to assert if a value is normal or not, based on:
# - the two data distributions
# - the tested value anomaly score
#
# ***queenless beehive 4 stand out but queenless beehive 3 not so much and we also risk to falk beehive 6 as queenless despite not being labelled as such***

# %% [markdown]
# ### queenless vs queenright

# %%
anomalies.discrimination_figure_from_investigated_scores_and_baseline_scores(
    anomaly_scores_from_dataframe(queenless_features_dataframe),
    anomaly_scores_from_dataframe(queenright_features_dataframe),
).savefig(
    paths.pictures_folderpath + 'queenless_versus_queenright_discrimination', 
    dpi=150,    
)

# %% [markdown]
# ### single beehive queenless data vs queenright baseline

# %%
anomalies.discrimination_figure_from_investigated_scores_and_baseline_scores(
    anomaly_scores_from_dataframe(queenless_features_dataframe_hive_03),
    anomaly_scores_from_dataframe(queenright_features_dataframe),
).savefig(
    paths.pictures_folderpath + 'hive_03_queenless_versus_queenright_discrimination', 
    dpi=150,    
)

# %%
anomalies.discrimination_figure_from_investigated_scores_and_baseline_scores(
    anomaly_scores_from_dataframe(queenless_features_dataframe_hive_04),
    anomaly_scores_from_dataframe(queenright_features_dataframe),
).savefig(
    paths.pictures_folderpath + 'hive_04_queenless_versus_queenright_discrimination', 
    dpi=150,    
)

# %% [markdown]
# ### single beehive queenless data vs same beehive queenright baseline

# %%
anomalies.discrimination_figure_from_investigated_scores_and_baseline_scores(
    anomaly_scores_from_dataframe(queenless_features_dataframe_hive_04),
    anomaly_scores_from_dataframe(queenright_features_dataframe_hive_04),
);

# %%
anomalies.discrimination_figure_from_investigated_scores_and_baseline_scores(
    anomaly_scores_from_dataframe(queenless_features_dataframe_hive_03),
    anomaly_scores_from_dataframe(queenright_features_dataframe_hive_03),
);

# %% [markdown]
# ### single beehive queenright data vs same beehive queenright baseline over different periods
# ***beehive 2 does not exhibit different pattern until and from 12 periods but beehive 6 does***

# %%
hive_label = 'hive_02'
pool = all_features
one_hive = pool[pool['hive'] == hive_label]
til_twelveth = one_hive[
        one_hive['timestamp'] < numpy.datetime64('2026-03-12')
    ]
from_twelveth = one_hive[
        one_hive['timestamp'] >= numpy.datetime64('2026-03-12')
    ]
anomalies.discrimination_figure_from_investigated_scores_and_baseline_scores(
    anomaly_scores_from_dataframe(from_twelveth),
    anomaly_scores_from_dataframe(til_twelveth),
);

# %%
hive_label = 'hive_06'
pool = all_features
one_hive = pool[pool['hive'] == hive_label]
til_twelveth = one_hive[
        one_hive['timestamp'] < numpy.datetime64('2026-03-12')
    ]
from_twelveth = one_hive[
        one_hive['timestamp'] >= numpy.datetime64('2026-03-12')
    ]
anomalies.discrimination_figure_from_investigated_scores_and_baseline_scores(
    anomaly_scores_from_dataframe(from_twelveth),
    anomaly_scores_from_dataframe(til_twelveth),
).savefig(
    paths.pictures_folderpath + 'hive_06_before_and_after_twelfth_discrimination', 
    dpi=150,    
)

# %% [markdown]
# ## mosaic monitoring
# we show each selected feature anomaly score for each hour for both queenless and queenright data
# - anomaly score on the left (negative = abnormal | positive = normal)
# - features colored by type
# - features clustered by redundance
# since all queenrigt data are expected to be given as baseline a aprameter indicate for each hour which score is shown:
# - worst -> the lowest anomaly score
# - best -> the highest anomaly score
# - closest -> the closest from the investigated queenless data at that hour
# - furthest -> the fursthest from the investigated queenless data at that hour
# - a number -> that beehive
# - mean -> all queenright beehives anomaly score averaged

# %%
anomalies.investigate_anomaly(
    investigated_features_dataframe=queenless_features_dataframe,
    baseline_features_dataframe=queenright_features_dataframe,
    baseline_aggregation='closest',
    observation_period='join',
    anomaly_scores_from_dataframe = anomaly_scores_from_dataframe,
    plotly=False,
).savefig(
    paths.pictures_folderpath + 'mosaic_pyplot',
    dpi=150,
)

# %%
anomalies.investigate_anomaly(
    investigated_features_dataframe=queenless_features_dataframe,
    baseline_features_dataframe=queenright_features_dataframe,
    baseline_aggregation='closest',
    observation_period='join',
    anomaly_scores_from_dataframe = anomaly_scores_from_dataframe,
    plotly=True,
)
