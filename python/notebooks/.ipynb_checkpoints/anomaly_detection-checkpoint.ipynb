# %%
import dataframes
import anomalies
import paths
import numpy
import pandas

# %%
def anomaly_scores_from_dataframe_from_inliers_dataframe(inliers_dataframe):
    scorers = anomalies.scorers_from_inliers_dataframe_and_detector(
        inliers_dataframe,
        
        # IsolationForest(random_state=42),
        # LocalOutlierFactor(novelty=True),
        OneClassSVM(),
        
        # # EllipticEnvelope(random_state=42), # not suitable for hour slices

    )
    return lambda dataframe: anomalies.anomaly_scores_from_dataframe_and_scorers(dataframe, scorers)

# %%
all_features = dataframes.from_filepath(paths.all_merged_features_filepath)

# %%
queenright_features_dataframe = all_features[all_features['queenlessness'] == False]
queenless_features_dataframe = all_features[all_features['queenlessness'] == True]

# %%
queenless_features_dataframe_hive_03 = queenless_features_dataframe[
    queenless_features_dataframe['hive'] == "hive_03"
]
queenless_features_dataframe_hive_04 = queenless_features_dataframe[
    queenless_features_dataframe['hive'] == "hive_04"
]

# %%
queenright_features_dataframe_hive_03 = queenright_features_dataframe[
    queenright_features_dataframe['hive'] == "hive_03"
]
queenright_features_dataframe_hive_04 = queenright_features_dataframe[
    queenright_features_dataframe['hive'] == "hive_04"
]

# %%
anomaly_scores_from_dataframe = anomalies.anomaly_scores_from_dataframe_from_inliers_dataframe(
    queenright_features_dataframe
)

# %%
from matplotlib import pyplot

def histogram_from_array(array, bins=50, title="Histogram"):
    pyplot.figure()
    pyplot.hist(array, bins=bins)
    pyplot.title(title)
    pyplot.show()

# %%
histogram_from_array(anomaly_scores_from_dataframe(queenright_features_dataframe))

# %%
histogram_from_array(anomaly_scores_from_dataframe(queenless_features_dataframe_hive_03))

# %%
histogram_from_array(anomaly_scores_from_dataframe(queenless_features_dataframe_hive_04))

# %%
def investigate_anomaly(
    investigated_features_dataframe,
    baseline_features_dataframe,
    baseline_aggreagation,
):

    baseline_zscores = dataframes.zscored_dataframe_from_dataframe_and_baseline(
        baseline_features_dataframe, baseline_features_dataframe,
    )
    investigated_zscores = dataframes.zscored_dataframe_from_dataframe_and_baseline(
        investigated_features_dataframe, queenright_features_dataframe,
    )
    
    # reorder columns by feature similarity
    baseline_zscores = dataframes.reordered_columns_from_dataframe(baseline_zscores)
    investigated_zscores = investigated_zscores[baseline_zscores.columns]
    
    # anomaly scores
    baseline_anomaly_scores = anomaly_scores_from_dataframe(queenright_features_dataframe)
    investigated_anomaly_scores = anomaly_scores_from_dataframe(investigated_features_dataframe)
    
    # mosaic

    anomalies.mosaic_from_zscored_dataframes_and_scores(
        investigated_zscores=investigated_zscores,                          # queenless z-scores (top panel)
        investigated_anomaly_scores=investigated_anomaly_scores,               # queenless anomaly scores (top left column)
        investigated_timestamps=queenless_features_dataframe["timestamp"],  # y-axis labels for top panel
        baseline_zscores=baseline_zscores,                                  # queenright z-scores (bottom panel)
        baseline_anomaly_scores=baseline_anomaly_scores,                  # queenright anomaly scores (bottom left column)
        baseline_timestamps=baseline_features_dataframe["timestamp"],     # y-axis labels for bottom panel
        baseline_hives=baseline_features_dataframe["hive"],               # needed to filter/aggregate by hive
        aggregation_method=baseline_aggreagation,                         # show hive_06 as the baseline comparison
    )

# %%
queenless_features_dataframe_hive_03
# Out:
#               timestamp     hive time_slice  spectral_centroid_mean  \
# 579 2026-03-12 00:00:00  hive_03      00-01             2151.822532
# 580 2026-03-12 01:00:00  hive_03      01-02             2133.194130
# 581 2026-03-12 02:00:00  hive_03      02-03             2106.492707
# 582 2026-03-12 03:00:00  hive_03      03-04             2127.585467
# 583 2026-03-12 04:00:00  hive_03      04-05             1942.191172
# ..                  ...      ...        ...                     ...
# 807 2026-03-21 12:00:00  hive_03      12-13             1704.899687
# 808 2026-03-21 13:00:00  hive_03      13-14             1658.207778
# 809 2026-03-21 14:00:00  hive_03      14-15             1611.940591
# 810 2026-03-21 15:00:00  hive_03      15-16             1723.165802
# 811 2026-03-21 16:00:00  hive_03      16-17             1788.105308
#
#      spectral_centroid_std  spectral_bandwidth_mean  spectral_bandwidth_std  \
# 579             174.803960              2601.277098               95.489887
# 580             212.705614              2574.781514              105.873812
# 581             143.465101              2537.477183               88.400852
# 582             197.398233              2531.819721              115.896069
# 583             157.406464              2421.666818               94.801212
# ..                     ...                      ...                     ...
# 807             170.921731              2193.658657              133.636790
# 808             254.966467              2134.904009              150.863012
# 809             292.272857              2106.107958              312.688169
# 810             211.761098              2272.016025              219.135297
# 811             165.458835              2294.174927              109.166862
#
#      spectral_rolloff_mean  spectral_rolloff_std  spectral_flatness_mean  ...  \
# 579            5998.824142            435.300200                0.034677  ...
# 580            5891.014446            502.507963                0.036320  ...
# 581            5777.171135            372.324958                0.036774  ...
# 582            5759.319906            516.325956                0.039651  ...
# 583            5299.525767            440.192947                0.032291  ...
# ..                     ...                   ...                     ...  ...
# 807            4266.419919            611.601062                0.029027  ...
# 808            4026.783581            695.565010                0.028039  ...
# 809            4024.415752            923.851537                0.041135  ...
# 810            4702.131546            654.783365                0.033157  ...
# 811            4843.332873            485.358495                0.029725  ...
#
#      middle_to_high_energy_ratio_std  low_modulation_energy  \
# 579                         0.187976           1.542767e+06
# 580                         0.189068           1.478681e+06
# 581                         0.192017           1.322220e+06
# 582                         0.179495           1.516703e+06
# 583                         0.193709           1.447539e+06
# ..                               ...                    ...
# 807                         0.277690           2.740152e+06
# 808                         0.337005           3.479920e+06
# 809                         0.359920           7.079209e+06
# 810                         0.290815           7.259421e+06
# 811                         0.293072           1.534980e+06
#
#      low_peak_modulation_frequency  middle_modulation_energy  \
# 579                       6.344195              1.807421e+06
# 580                      15.865071              1.874027e+06
# 581                       3.403904              1.800380e+06
# 582                       3.831128              1.748504e+06
# 583                       3.288626              1.736737e+06
# ..                             ...                       ...
# 807                      10.426713              8.475324e+06
# 808                       1.095005              8.127734e+06
# 809                       2.075009              1.502906e+07
# 810                       6.098916              1.467350e+07
# 811                       6.308683              2.248688e+06
#
#      middle_peak_modulation_frequency  high_modulation_energy  \
# 579                          3.470571            1.009656e+06
# 580                          1.031949            1.028107e+06
# 581                          1.529173            1.014962e+06
# 582                          3.841406            1.029697e+06
# 583                          2.842513            1.008102e+06
# ..                                ...                     ...
# 807                          1.301672            5.911568e+06
# 808                          1.328061            5.297494e+06
# 809                          1.014449            1.527384e+07
# 810                         21.938986            1.506581e+07
# 811                          2.233097            1.224215e+06
#
#      high_peak_modulation_frequency  queenlessness  temperature   humidity
# 579                       16.577018           True     8.997499  75.695000
# 580                        4.970855           True     8.857500  75.982500
# 581                        4.224741           True     8.965000  76.352500
# 582                        2.327233           True     8.795000  76.515000
# 583                        1.112783           True     8.167500  75.395004
# ..                              ...            ...          ...        ...
# 807                        1.941953           True    13.440000  51.400000
# 808                        1.600007           True    15.215000  47.370003
# 809                        1.339450           True    15.320000  47.640000
# 810                        1.373062           True    15.434999  44.887497
# 811                        7.893224           True    12.680000  48.157500
#
# [233 rows x 108 columns]

# %%
anomalies.discrimination_figure_from_investigated_scores_and_baseline_scores(
    anomaly_scores_from_dataframe(queenless_features_dataframe_hive_03),
    anomaly_scores_from_dataframe(queenright_features_dataframe_hive_03),
);

# %%
investigate_anomaly(
    queenless_features_dataframe_hive_04,
    queenright_features_dataframe,
    2,
)

# %%
baseline_zscores = dataframes.zscored_dataframe_from_dataframe_and_baseline(
    queenright_features_dataframe, queenright_features_dataframe,
)
investigated_zscores = dataframes.zscored_dataframe_from_dataframe_and_baseline(
    queenless_features_dataframe_hive_04, queenright_features_dataframe,
)

# reorder columns by feature similarity
baseline_zscores = dataframes.reordered_columns_from_dataframe(baseline_zscores)
investigated_zscores = investigated_zscores[baseline_zscores.columns]

# anomaly scores
queenright_anomaly_scores = anomaly_scores_from_dataframe(queenright_features_dataframe)
queenless_anomaly_scores = anomaly_scores_from_dataframe(queenless_features_dataframe_hive_04)

# population discrimination
print(anomalies.discrimination_from_scores_and_scores(queenless_anomaly_scores, queenright_anomaly_scores))

# mosaic
anomalies.mosaic_from_zscored_dataframes_and_scores(
    investigated_zscores=investigated_zscores,
    investigated_anomaly_scores=queenless_anomaly_scores,
    investigated_timestamps=queenless_features_dataframe["timestamp"],
    baseline_zscores=baseline_zscores,
    baseline_anomaly_scores=queenright_anomaly_scores,
    baseline_timestamps=queenright_features_dataframe["timestamp"],
    baseline_hives=queenright_features_dataframe["hive"],
    aggregation_method=2,
);
# Out:
# {'mann_whitney_u': np.float64(11169.0), 'p_value': np.float64(1.5059739316644117e-28), 'area_under_curve': np.float64(0.8943050193050193), 'cohens_d': np.float64(1.8691837234524422), 'investigated_median': np.float64(2.6360294623393594), 'baseline_median': np.float64(5.67247824426715)}

# %%
baseline_zscores = dataframes.zscored_dataframe_from_dataframe_and_baseline(
    queenright_features_dataframe, queenright_features_dataframe,
)
investigated_zscores = dataframes.zscored_dataframe_from_dataframe_and_baseline(
    queenless_features_dataframe, queenright_features_dataframe,
)

# reorder columns by feature similarity
baseline_zscores = dataframes.reordered_columns_from_dataframe(baseline_zscores)
investigated_zscores = investigated_zscores[baseline_zscores.columns]

# anomaly scores
queenright_anomaly_scores = anomaly_scores_from_dataframe(queenright_features_dataframe)
queenless_anomaly_scores = anomaly_scores_from_dataframe(queenless_features_dataframe)

# population discrimination
print(anomalies.discrimination_from_scores_and_scores(queenless_anomaly_scores, queenright_anomaly_scores))

# mosaic
anomalies.mosaic_from_zscored_dataframes_and_scores(
    investigated_zscores=investigated_zscores,
    investigated_anomaly_scores=queenless_anomaly_scores,
    investigated_timestamps=queenless_features_dataframe["timestamp"],
    baseline_zscores=baseline_zscores,
    baseline_anomaly_scores=queenright_anomaly_scores,
    baseline_timestamps=queenright_features_dataframe["timestamp"],
    baseline_hives=queenright_features_dataframe["hive"],
    aggregation_method=2,
);
# Out:
# {'mann_whitney_u': np.float64(216536.0), 'p_value': np.float64(0.020739713468203715), 'area_under_curve': np.float64(0.53707290584367), 'cohens_d': np.float64(0.2721533352008932), 'investigated_median': np.float64(5.607376545621627), 'baseline_median': np.float64(5.67247824426715)}

# %%
anomalies.discrimination_figure_from_scores_and_scores(
    queenless_anomaly_scores,
    queenright_anomaly_scores,
);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 anomalies.discrimination_figure_from_scores_and_scores(
#       2     queenless_anomaly_scores,
#       3     queenright_anomaly_scores,
#       4 );
#
# AttributeError: module 'anomalies' has no attribute 'discrimination_figure_from_scores_and_scores'
